# %% [markdown]
# ## A social network has been hacked!
#
# You have been able to get a hold of the list of users affected and need to notify a credit card blocking service.
#
#
# Example derived from: https://gist.github.com/jorin-vogel/2e43ffa981a97bc17259
#
# - - -

# %%
ls *.json
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 5677-52D0
#
#  Directory of C:\Users\Nathan\Documents\GitHub\notebooks\Introductions
#
# 26/04/2015  10:56 AM         2,382,898 social.json
#                1 File(s)      2,382,898 bytes
#                0 Dir(s)  208,531,562,496 bytes free

# %%
import pandas as pd

# %%
dataset = pd.read_json("social.json")

# %%
dataset.columns
# Out:
# Index(['city', 'creditcard', 'email', 'mac', 'name', 'timestamp'], dtype='object')

# %%
dataset[['name', 'creditcard']]
# Out:
#                          name           creditcard
# 0                Keeley Bosco  1228-1221-1221-1431
# 1                 Rubye Jerde  1228-1221-1221-1431
# 2     Miss Darian Breitenberg                 None
# 3            Celine Ankunding  1228-1221-1221-1431
# 4            Dr. Araceli Lang  1211-1221-1234-2201
# 5                 Esteban Von                 None
# 6              Everette Swift                 None
# 7               Terrell Boyle  1228-1221-1221-1431
# 8           Miss Emmie Muller                 None
# 9                Libby Renner  1234-2121-1221-1211
# 10               Kris Spencer                 None
# 11          Terrance Schiller                 None
# 12          Alessandro Barton  1234-2121-1221-1211
# 13             Dr. Art Grimes  1211-1221-1234-2201
# 14                Keven Purdy  1211-1221-1234-2201
# 15         William Wisozk DVM                 None
# 16                  Oma Grady  1212-1221-1121-1234
# 17          Annie Schamberger                 None
# 18             Jazmin Kovacek  1211-1221-1234-2201
# 19            Thomas O'Conner                 None
# 20         Jordi Jaskolski II  1212-1221-1121-1234
# 21           Willy Beahan III  1212-1221-1121-1234
# 22       Alessandra Nader Sr.  1211-1221-1234-2201
# 23               Leora Heller                 None
# 24        Crystel Satterfield                 None
# 25              Neal Nitzsche                 None
# 26            Ramona Lubowitz  1228-1221-1221-1431
# 27      Miss Brock Macejkovic                 None
# 28        Mrs. Keyon Bergnaum                 None
# 29                 Renee Hand                 None
# ...                       ...                  ...
# 9970                Orlo Yost                 None
# 9971       Mr. Myriam Gerlach                 None
# 9972            Dax Brekke II  1234-2121-1221-1211
# 9973       Brando Stanton Jr.  1228-1221-1221-1431
# 9974      Lacey McDermott PhD                 None
# 9975               Elza Bauch                 None
# 9976              Zaria Lesch                 None
# 9977          Natalia Toy DVM  1234-2121-1221-1211
# 9978            Major Weimann                 None
# 9979               Saige Conn  1212-1221-1121-1234
# 9980           Golden Padberg                 None
# 9981            Joseph Kirlin                 None
# 9982          Kale Hodkiewicz  1211-1221-1234-2201
# 9983          Chloe Kertzmann                 None
# 9984               Fiona Lang  1234-2121-1221-1211
# 9985               Ayla Boyle                 None
# 9986         Aracely Kassulke                 None
# 9987     Mrs. Felicia Quitzon  1212-1221-1121-1234
# 9988    Annabell Armstrong II  1212-1221-1121-1234
# 9989        Mr. Jaylin Brekke                 None
# 9990     Lloyd Heidenreich IV  1228-1221-1221-1431
# 9991           Ms. Mose Hilll  1234-2121-1221-1211
# 9992             Allan Herman  1211-1221-1234-2201
# 9993             Enos Padberg                 None
# 9994        Dr. Geovanny Metz                 None
# 9995       Jaqueline Walter I                 None
# 9996           Isobel Reinger  1228-1221-1221-1431
# 9997          Chelsea Shields  1211-1221-1234-2201
# 9998          Luciano Gutmann  1234-2121-1221-1211
# 9999         Austin Langworth  1212-1221-1121-1234
#
# [10000 rows x 2 columns]
